# %%
#initial imports for data manipulation, regression modeling, and visualization

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets, linear_model
sns.set()

# %%
# creates a dataframe with used FORD car prices collected in 2020 in the UK from kaggle.com 
# source = https://www.kaggle.com/adityadesai13/used-car-dataset-ford-and-mercedes

df = pd.read_csv(r"C:\Users\14802\devmtn\data15\week4\regression\used_car_prices_by_brand_UK\ford.csv")

# %%
# initial look at the dataframe
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
# first look at scatterplots to see overview of variables' relationships
sns.pairplot(df)

# %%
# scatterplot to take a closer look at the relationship of mileage and price

sns.scatterplot(data=df, x="mileage", y="price");

# %%
# scatterplot to take a closer look at the relationship between price and year

sns.scatterplot(data=df, x="year", y="price")
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %% [markdown]
# <span style="color:green">In the above scatterplot, an outlier is observed at the year 2060. Because this data was collected in 2020, I know this is inaccurate and will go ahead and drop the outlier.</span>

# %%
# identifies the row with the outlier
df.query('year > 2020')
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 17726   Fiesta  2060   6495    Automatic    54807   Petrol  205  42.8
#
#        engineSize
# 17726         1.4

# %%
# drops the outlier
df.drop(index={17726}, inplace=True)

# %%
#recreates the scatterplot between price and year
sns.scatterplot(data=df, x="year", y="price")
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>
